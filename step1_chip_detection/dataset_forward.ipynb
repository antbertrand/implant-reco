# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import chip_detector
from chip_detector import ChipDetector

# automatically reload modules when they have changed
# %load_ext autoreload
# %autoreload 2
# Out:
# Using TensorFlow backend.

# %%
a = ChipDetector()
# Out:
# WARNING:tensorflow:From /home/abert/.virtualenvs/test/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /home/abert/.virtualenvs/test/lib/python3.6/site-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
import os 
import cv2

# %%
im_path = '/home/abert/Documents/NumeriCube/eurosilicone/gcaesthetics-implantbox/dataset/step1_detector/img_train/'
output_path = '/home/abert/Documents/NumeriCube/eurosilicone/gcaesthetics-implantbox/dataset/step2_orientationfixer/img_train/'
filenames = os.listdir(im_path)

for filename in filenames:
    print(filename)
    im = cv2.imread(im_path+filename,0)

    box, score = a.detect_chip(im)
    if box is None:
        print("The chip was not detected properly. Please try again !")
    elif score < 0.1:
        print("The confidence is too low on the classification")
    else:
        box = box.astype(int)
        crop_im = im[box[1]:box[3],box[0]:box[2]]
        cv2.imwrite(output_path+filename,crop_im)
        print(box)
# Out:
# FULL-2019-04-26-161428.png
# [1331.6183   441.52463 3064.5203  2232.141  ] 0.98502165 0
# The confidence on the classification is of 98.50216507911682%
# [1331  441 3064 2232]
# FULL-2019-05-16-144924.png
# [1597.0599    69.81298 3305.1477  1767.653  ] 0.98716414 0
# The confidence on the classification is of 98.71641397476196%
# [1597   69 3305 1767]
# FULL-2019-05-16-143043.png
# [1860.3202   839.02216 3628.691   2634.9119 ] 0.8761203 0
# The confidence on the classification is of 87.61203289031982%
# [1860  839 3628 2634]
# FULL-2019-05-16-150054.png
# [1956.3381  242.8342 3647.8416 2016.9944] 0.9848233 0
# The confidence on the classification is of 98.48232865333557%
# [1956  242 3647 2016]
# FULL-2019-05-16-151352.png
# [1166.7107    0.     2892.1455 1592.866 ] 0.9838344 0
# The confidence on the classification is of 98.38343858718872%
# [1166    0 2892 1592]
# FULL-2019-05-16-142713.png
# [2366.6362   430.24026 3646.2302  1676.1587 ] 0.87209356 0
# ...
