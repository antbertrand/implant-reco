# %%
import json
import os 
from PIL import Image
import cv2 as cv2
import numpy as np
import math
import imutils
import random

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
IMAGES_PATH = '/home/abert/Documents/NumeriCube/eurosilicone/angle/ds/img_corr_resized/'  
OUTPUT_PATH = '/home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/'
images = os.listdir(IMAGES_PATH)

for index, im in enumerate(images):
    #im = '/home/abert/Documents/NumeriCube/eurosilicone/angle/ds/img_corr_resized/FULL-2019-04-26-155346.png'
    print(im)
    img = cv2.imread(IMAGES_PATH + im)
    #img = cv2.imread(im)
    img2 = cv2.resize(img, (224, 224))
    
    # Create test / train / valdiation directories
    dir_train = OUTPUT_PATH + 'train/'
    dir_test = OUTPUT_PATH+ 'test/'
    dir_val = OUTPUT_PATH+ 'val/'
    if not os.path.exists(dir_train):
            os.makedirs(dir_train)
    if not os.path.exists(dir_test):
            os.makedirs(dir_test)
    if not os.path.exists(dir_val):
            os.makedirs(dir_val) 
    
    ndir = index%5
    
        
    if ndir >=0 and ndir <3:
        dir_final = dir_train
        write = 0

                
    if ndir ==3:
        dir_final = dir_val
        write = 1
        

        
    if ndir ==4:
        dir_final = dir_test   
        write = 1
        
    if write == 1:
        for k in range(0,360):

            img3 = imutils.rotate(img2,k)
            k_3 = "{:03d}".format(k)
            output_dir = dir_final + str(k_3) + '/'
            print(output_dir)

            if not os.path.exists(output_dir):
                os.makedirs(output_dir)
            cv2.imwrite( output_dir+im, img3 )




            

    #print('image ', k, 'done')
        
        
    print('finito')
# Out:
# FULL-2019-04-26-154943.png
# finito
# FULL-2019-04-26-161428.png
# finito
# FULL-2019-04-26-143540.png
# finito
# FULL-2019-04-26-155346.png
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/000/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/001/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/002/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/003/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/004/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/005/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/006/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/007/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/008/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/009/
# /home/abert/Documents/NumeriCube/eurosilicone/angle/ds/ds_rotated/val/010/
# ...

# %%
 a = "{:05d}".format(1)
    
print(a)
# Out:
# 00001
